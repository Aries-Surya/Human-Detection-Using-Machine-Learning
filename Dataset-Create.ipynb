# %% [markdown]
# # **Data-Set Processing**

# %% [markdown]
# ## Extract Frames from Video

# %%
import cv2
import os

# Define input video path
video_path = "Input/Vid/saec.mp4"
output_folder = "dataset-create/images"

# Create output directory if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Open video file
cap = cv2.VideoCapture(video_path)
frame_rate = cap.get(cv2.CAP_PROP_FPS)  # Get frames per second
frame_interval = int(frame_rate)  # Extract 1 frame per second

frame_count = 0
saved_count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # Stop if video ends

    # Save frame every 1 second
    if frame_count % frame_interval == 0:
        frame_filename = f"{output_folder}/frame_{saved_count}.jpg"
        cv2.imwrite(frame_filename, frame)
        saved_count += 1

    frame_count += 1

cap.release()
cv2.destroyAllWindows()

print(f"Extracted {saved_count} frames and saved to {output_folder}")
# Out:
# Extracted 33 frames and saved to dataset-create/images

# %% [markdown]
# ## Annotate Frames (Bounding Boxes for Objects)

# %% [raw]
# https://app.roboflow.com/surya-learning/humandetection-from-highaltitude/annotate

# %% [markdown]
# ## Save Annotations in YOLO Format

# %% [markdown]
# ## Organize Data for Training

# %% [markdown]
# ## Train YOLO Model on New Dataset
